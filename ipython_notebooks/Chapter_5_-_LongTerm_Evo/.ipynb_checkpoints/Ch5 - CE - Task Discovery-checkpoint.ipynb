# %%
import glob
import csv
import math
import collections
import os.path
from sets import Set
import sys

import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import seaborn as sns
sns.set_context('paper', font_scale=2)
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import gridspec
import scipy  
import scikits.bootstrap as bootstrap
#from scipy import stats
import scipy.stats as ss
import matplotlib.gridspec as gridspec
#from IPython.display import Image

from PIL import Image
from IPython.display import Image as ipyImage

import prettyplotlib as ppl
from matplotlib.colors import LogNorm
from prettyplotlib import brewer2mpl


#%pylab inline
# %matplotlib inline
plt.rcParams['figure.figsize'] = (8, 4)
# %rehashx

#import mpld3
#mpld3.enable_notebook()

pd.__version__
# Out:
# u'0.20.3'

# %%
data_path = ""
scripts_path = ""
analysis_directory = ""
data_name = ""

# %%
def add_treatment(dic, series, name, seed, longname=None, shortid=None, 
                  factors={}, skip_seeds=None,
                  location=None, filename=None):
    shortlabel = name
    if series:
        shortlabel = series + "_" + name
        
    if not longname:
        longname = "\n".join( name.split("_") )
                        
    if not location:        
        location = series + "_" + name + "_" + seed
    
    if skip_seeds == None:
        skip_seeds = []
    
    dic[shortlabel] = {'longlabel': longname, 'shortlabel': shortlabel, 'series': series, 'id': shortid,
                  'dir': location, 'filename': filename, 'factors': factors, 'skip': skip_seeds}

# %%
data_name = "CA_GrazingHypothesis_LongTermEvolution"
data_number = "CA-1"

treatments = collections.OrderedDict()
add_treatment(treatments, series="CA-1", seed="104", name="Z1_HGT_B0.0", shortid="Z1",
              factors={'Bonus':"B0.0", 'Env':"Static", 'Quiesce': "True", 'Exp': 'A'})
add_treatment(treatments, series="CA-1", seed="104", name="Z2_noHGT_B0.0",  shortid="Z2",
              factors={'Bonus':"B0.0", 'Env':"Static", 'Quiesce': "True", 'Exp': 'B'})
add_treatment(treatments, series="CA-1", seed="104", name="Z3_noHGT_B0.0_CE", shortid="Z3", 
              factors={'Bonus':"B0.0", 'Env':"CE", 'Quiesce': "True", 'Exp': 'B'})
add_treatment(treatments, series="CA-1", seed="104", name="Z4_noHGT_B0.0_CEq", shortid="Z4", 
              factors={'Bonus':"B0.0", 'Env':"CE", 'Quiesce': "False", 'Exp': 'B'})

add_treatment(treatments, series="CA-1", seed="104", name="Z5_noHGT_B0.0_CE_benign", shortid="Z5", 
              factors={'Bonus':"B0.0", 'Env':"CE", 'Quiesce': "True", 'Exp': 'B'})
add_treatment(treatments, series="CA-1", seed="104", name="Z6_noHGT_B0.0_CEq_benign", shortid="Z6", 
              factors={'Bonus':"B0.0", 'Env':"CE", 'Quiesce': "False"})

add_treatment(treatments, series="CA-1", seed="104", name="Z7_HGT_B0.0_nologic77", shortid="Z7", 
              factors={'Bonus':"B0.0", 'Env':"Static", 'Quiesce': "True", 'Exp': 'B'})
add_treatment(treatments, series="CA-1", seed="104", name="Z8_noHGT_B0.0_nologic77", shortid="Z8", 
              factors={'Bonus':"B0.0", 'Env':"Static", 'Quiesce': "True", 'Exp': 'B'})



add_treatment(treatments, series="CA-1", seed="104", name="A1_HGT_B0.0_CE", shortid="A1", 
              factors={'Bonus':"B0.0", 'Env':"CE", 'Quiesce': "False", 'Exp': 'A'})
add_treatment(treatments, series="CA-1", seed="104", name="A5_HGT_B0.0_CEq", shortid="A5", 
              factors={'Bonus':"B0.0", 'Env':"CE", 'Quiesce': "True", 'Exp': 'B'})

add_treatment(treatments, series="CA-1", seed="104", name="A2_HGT_B0.8", shortid="A2", 
              factors={'Bonus':"B0.8", 'Env':"Static", 'Quiesce': "True", 'Exp': 'A'})
add_treatment(treatments, series="CA-1", seed="104", name="A3_HGT_B1.6", shortid="A3", 
              factors={'Bonus':"B1.6", 'Env':"Static", 'Quiesce': "True", 'Exp': 'A'})

add_treatment(treatments, series="CA-1", seed="104", name="A4_HGT_B0.8_CE", shortid="A4", 
              factors={'Bonus':"B0.8", 'Env':"CE", 'Quiesce': "False", 'Exp': 'A'})
add_treatment(treatments, series="CA-1", seed="104", name="A6_HGT_B0.8_CEq", shortid="A6", 
              factors={'Bonus':"B0.8", 'Env':"CE", 'Quiesce': "True", 'Exp': 'B'})


add_treatment(treatments, series="CA-1", seed="104", name="B1_HGT_B0.0_CE_benign", shortid="B1", 
              factors={'Bonus':"B0.0", 'Env':"CE", 'Quiesce': "False", 'Exp': 'B'})
add_treatment(treatments, series="CA-1", seed="104", name="B5_HGT_B0.0_CEq_benign", shortid="B5", 
              factors={'Bonus':"B0.0", 'Env':"CE", 'Quiesce': "True", 'Exp': 'B'})

add_treatment(treatments, series="CA-1", seed="104", name="B4_HGT_B0.8_CE_benign", shortid="B4", 
              factors={'Bonus':"B0.8", 'Env':"CE", 'Quiesce': "False", 'Exp': 'B'})
add_treatment(treatments, series="CA-1", seed="104", name="B6_HGT_B0.8_CEq_benign", shortid="B6", 
              factors={'Bonus':"B0.8", 'Env':"CE", 'Quiesce': "True", 'Exp': 'B'})


#print treatments

# %%
def setup_analysis_path(treatments, 
    base_path="/Core/home/rosiec/__research/HGT/raw_data/", 
    scripts="~/Dropbox/School_Docs/Research/research_scripts/", 
                        verbose=False):
    
    global analysis_directory
    analysis_directory = "analysis"
    
    ## generated
    data_directory = "_".join(data_name.split(" "))
    global data_path
    data_path = base_path + data_directory
    analysis_path = data_path + "/" + analysis_directory
    global scripts_path
    scripts_path = scripts
    
#    global scripts_path
#    scripts_path = scripts_path

    if verbose:
        print "base_path:", base_path
        print "scripts_path:", scripts_path
        print "data_path:",data_path
        print "analysis_path", analysis_path
        print
        print "Treatments:"
        print treatments.keys()
        print
        print "Values:"
        for val in treatments.values():
            print val

# %%
def prepare_analysis_directories(treatments, skipchecks=False, cleanup=True, verbose=False, length=200000):

    if verbose:
        print data_path
    # %cd {data_path}
    # !mkdir incomplete
    #if verbose:
    #    !pwd
    #    %pwd
    #%mkdir incomplete
    if verbose:
        # !pwd
    #!ls
    
    if not skipchecks:
        bleh = []
        for t in treatments:
            print treatments[t]['dir']
            datafiles = glob.glob(data_path+'/'+treatments[t]['dir']+'*')
            for item in datafiles:

                filepath = item +"/data/count.dat"
                if os.path.isfile(filepath):
                    line = !tail -n 1 $filepath
                elif os.path.isfile(filepath+".gz"):
                    filepath = filepath+".gz"
                    line = !zcat $filepath | tail -n 1
                else:
                    if verbose:
                        print "count.dat[.gz] not found."
                    line = ""

                filepath = item +"/data/average.dat"
                if not os.path.isfile(filepath) and not os.path.isfile(filepath+".gz"):
                    if verbose:
                        print "average.dat[.gz] not found."
                    line = ""



                #print filepath
                #bleh = line
                #print line
                #line = line.split(' ')[0]
                #print line
                if len(line) == 0 or line[0].split(' ')[0] != str(length):
                    if verbose:
                        print "Incomplete", item, line
                    if cleanup:
                        # !mv $item incomplete/

    # %mkdir {analysis_directory}
    # %cd {analysis_directory}
    if verbose:
        # %pwd

    for t in treatments:
        print
        print t, ": " , len(glob.glob(data_path+'/'+treatments[t]['dir']+'*'))
        for v in treatments[t]:
            print "  ",v,": ", treatments[t][v]

# %%
pwd
# Out:
# u'/Core/home/rosiec/Dropbox/School_Docs/Dissertation/ipython_notebooks/Chapter_5_-_LongTerm_Evo'

# %%
## Call the init methods 
setup_analysis_path(treatments, 
    base_path="/Core/home/rosiec/__research/HGT/raw_data/FinalData/", 
                    verbose=True)
prepare_analysis_directories(treatments, skipchecks=False, 
    cleanup=True, verbose=False, length=400000)
# Out:
# base_path: /Core/home/rosiec/__research/HGT/raw_data/FinalData/
# scripts_path: ~/Dropbox/School_Docs/Research/research_scripts/
# data_path: /Core/home/rosiec/__research/HGT/raw_data/FinalData/CA_GrazingHypothesis_LongTermEvolution
# analysis_path /Core/home/rosiec/__research/HGT/raw_data/FinalData/CA_GrazingHypothesis_LongTermEvolution/analysis
#
# Treatments:
# ['CA-1_Z1_HGT_B0.0', 'CA-1_Z2_noHGT_B0.0', 'CA-1_Z3_noHGT_B0.0_CE', 'CA-1_Z4_noHGT_B0.0_CEq', 'CA-1_Z5_noHGT_B0.0_CE_benign', 'CA-1_Z6_noHGT_B0.0_CEq_benign', 'CA-1_Z7_HGT_B0.0_nologic77', 'CA-1_Z8_noHGT_B0.0_nologic77', 'CA-1_A1_HGT_B0.0_CE', 'CA-1_A5_HGT_B0.0_CEq', 'CA-1_A2_HGT_B0.8', 'CA-1_A3_HGT_B1.6', 'CA-1_A4_HGT_B0.8_CE', 'CA-1_A6_HGT_B0.8_CEq', 'CA-1_B1_HGT_B0.0_CE_benign', 'CA-1_B5_HGT_B0.0_CEq_benign', 'CA-1_B4_HGT_B0.8_CE_benign', 'CA-1_B6_HGT_B0.8_CEq_benign']
#
# Values:
# {'shortlabel': 'CA-1_Z1_HGT_B0.0', 'skip': [], 'longlabel': 'Z1\nHGT\nB0.0', 'factors': {'Bonus': 'B0.0', 'Quiesce': 'True', 'Exp': 'A', 'Env': 'Static'}, 'series': 'CA-1', 'id': 'Z1', 'dir': 'CA-1_Z1_HGT_B0.0_104', 'filename': None}
# {'shortlabel': 'CA-1_Z2_noHGT_B0.0', 'skip': [], 'longlabel': 'Z2\nnoHGT\nB0.0', 'factors': {'Bonus': 'B0.0', 'Quiesce': 'True', 'Exp': 'B', 'Env': 'Static'}, 'series': 'CA-1', 'id': 'Z2', 'dir': 'CA-1_Z2_noHGT_B0.0_104', 'filename': None}
# {'shortlabel': 'CA-1_Z3_noHGT_B0.0_CE', 'skip': [], 'longlabel': 'Z3\nnoHGT\nB0.0\nCE', 'factors': {'Bonus': 'B0.0', 'Quiesce': 'True', 'Exp': 'B', 'Env': 'CE'}, 'series': 'CA-1', 'id': 'Z3', 'dir': 'CA-1_Z3_noHGT_B0.0_CE_104', 'filename': None}
# {'shortlabel': 'CA-1_Z4_noHGT_B0.0_CEq', 'skip': [], 'longlabel': 'Z4\nnoHGT\nB0.0\nCEq', 'factors': {'Bonus': 'B0.0', 'Quiesce': 'False', 'Exp': 'B', 'Env': 'CE'}, 'series': 'CA-1', 'id': 'Z4', 'dir': 'CA-1_Z4_noHGT_B0.0_CEq_104', 'filename': None}
# {'shortlabel': 'CA-1_Z5_noHGT_B0.0_CE_benign', 'skip': [], 'longlabel': 'Z5\nnoHGT\nB0.0\nCE\nbenign', 'factors': {'Bonus': 'B0.0', 'Quiesce': 'True', 'Exp': 'B', 'Env': 'CE'}, 'series': 'CA-1', 'id': 'Z5', 'dir': 'CA-1_Z5_noHGT_B0.0_CE_benign_104', 'filename': None}
# {'shortlabel': 'CA-1_Z6_noHGT_B0.0_CEq_benign', 'skip': [], 'longlabel': 'Z6\nnoHGT\nB0.0\nCEq\nbenign', 'factors': {'Bonus': 'B0.0', 'Quiesce': 'False', 'Env': 'CE'}, 'series': 'CA-1', 'id': 'Z6', 'dir': 'CA-1_Z6_noHGT_B0.0_CEq_benign_104', 'filename': None}
# {'shortlabel': 'CA-1_Z7_HGT_B0.0_nologic77', 'skip': [], 'longlabel': 'Z7\nHGT\nB0.0\nnologic77', 'factors': {'Bonus': 'B0.0', 'Quiesce': 'True', 'Exp': 'B', 'Env': 'Static'}, 'series': 'CA-1', 'id': 'Z7', 'dir': 'CA-1_Z7_HGT_B0.0_nologic77_104', 'filename': None}
# {'shortlabel': 'CA-1_Z8_noHGT_B0.0_nologic77', 'skip': [], 'longlabel': 'Z8\nnoHGT\nB0.0\nnologic77', 'factors': {'Bonus': 'B0.0', 'Quiesce': 'True', 'Exp': 'B', 'Env': 'Static'}, 'series': 'CA-1', 'id': 'Z8', 'dir': 'CA-1_Z8_noHGT_B0.0_nologic77_104', 'filename': None}
# {'shortlabel': 'CA-1_A1_HGT_B0.0_CE', 'skip': [], 'longlabel': 'A1\nHGT\nB0.0\nCE', 'factors': {'Bonus': 'B0.0', 'Quiesce': 'False', 'Exp': 'A', 'Env': 'CE'}, 'series': 'CA-1', 'id': 'A1', 'dir': 'CA-1_A1_HGT_B0.0_CE_104', 'filename': None}
# {'shortlabel': 'CA-1_A5_HGT_B0.0_CEq', 'skip': [], 'longlabel': 'A5\nHGT\nB0.0\nCEq', 'factors': {'Bonus': 'B0.0', 'Quiesce': 'True', 'Exp': 'B', 'Env': 'CE'}, 'series': 'CA-1', 'id': 'A5', 'dir': 'CA-1_A5_HGT_B0.0_CEq_104', 'filename': None}
# {'shortlabel': 'CA-1_A2_HGT_B0.8', 'skip': [], 'longlabel': 'A2\nHGT\nB0.8', 'factors': {'Bonus': 'B0.8', 'Quiesce': 'True', 'Exp': 'A', 'Env': 'Static'}, 'series': 'CA-1', 'id': 'A2', 'dir': 'CA-1_A2_HGT_B0.8_104', 'filename': None}
# {'shortlabel': 'CA-1_A3_HGT_B1.6', 'skip': [], 'longlabel': 'A3\nHGT\nB1.6', 'factors': {'Bonus': 'B1.6', 'Quiesce': 'True', 'Exp': 'A', 'Env': 'Static'}, 'series': 'CA-1', 'id': 'A3', 'dir': 'CA-1_A3_HGT_B1.6_104', 'filename': None}
# {'shortlabel': 'CA-1_A4_HGT_B0.8_CE', 'skip': [], 'longlabel': 'A4\nHGT\nB0.8\nCE', 'factors': {'Bonus': 'B0.8', 'Quiesce': 'False', 'Exp': 'A', 'Env': 'CE'}, 'series': 'CA-1', 'id': 'A4', 'dir': 'CA-1_A4_HGT_B0.8_CE_104', 'filename': None}
# {'shortlabel': 'CA-1_A6_HGT_B0.8_CEq', 'skip': [], 'longlabel': 'A6\nHGT\nB0.8\nCEq', 'factors': {'Bonus': 'B0.8', 'Quiesce': 'True', 'Exp': 'B', 'Env': 'CE'}, 'series': 'CA-1', 'id': 'A6', 'dir': 'CA-1_A6_HGT_B0.8_CEq_104', 'filename': None}
# {'shortlabel': 'CA-1_B1_HGT_B0.0_CE_benign', 'skip': [], 'longlabel': 'B1\nHGT\nB0.0\nCE\nbenign', 'factors': {'Bonus': 'B0.0', 'Quiesce': 'False', 'Exp': 'B', 'Env': 'CE'}, 'series': 'CA-1', 'id': 'B1', 'dir': 'CA-1_B1_HGT_B0.0_CE_benign_104', 'filename': None}
# {'shortlabel': 'CA-1_B5_HGT_B0.0_CEq_benign', 'skip': [], 'longlabel': 'B5\nHGT\nB0.0\nCEq\nbenign', 'factors': {'Bonus': 'B0.0', 'Quiesce': 'True', 'Exp': 'B', 'Env': 'CE'}, 'series': 'CA-1', 'id': 'B5', 'dir': 'CA-1_B5_HGT_B0.0_CEq_benign_104', 'filename': None}
# {'shortlabel': 'CA-1_B4_HGT_B0.8_CE_benign', 'skip': [], 'longlabel': 'B4\nHGT\nB0.8\nCE\nbenign', 'factors': {'Bonus': 'B0.8', 'Quiesce': 'False', 'Exp': 'B', 'Env': 'CE'}, 'series': 'CA-1', 'id': 'B4', 'dir': 'CA-1_B4_HGT_B0.8_CE_benign_104', 'filename': None}
# {'shortlabel': 'CA-1_B6_HGT_B0.8_CEq_benign', 'skip': [], 'longlabel': 'B6\nHGT\nB0.8\nCEq\nbenign', 'factors': {'Bonus': 'B0.8', 'Quiesce': 'True', 'Exp': 'B', 'Env': 'CE'}, 'series': 'CA-1', 'id': 'B6', 'dir': 'CA-1_B6_HGT_B0.8_CEq_benign_104', 'filename': None}
# /Core/home/rosiec/__research/HGT/raw_data/FinalData/CA_GrazingHypothesis_LongTermEvolution
# mkdir: cannot create directory ‘incomplete’: File exists
# CA-1_Z1_HGT_B0.0_104
# CA-1_Z2_noHGT_B0.0_104
# CA-1_Z3_noHGT_B0.0_CE_104
# CA-1_Z4_noHGT_B0.0_CEq_104
# CA-1_Z5_noHGT_B0.0_CE_benign_104
# CA-1_Z6_noHGT_B0.0_CEq_benign_104
# CA-1_Z7_HGT_B0.0_nologic77_104
# CA-1_Z8_noHGT_B0.0_nologic77_104
# CA-1_A1_HGT_B0.0_CE_104
# CA-1_A5_HGT_B0.0_CEq_104
# CA-1_A2_HGT_B0.8_104
# CA-1_A3_HGT_B1.6_104
# CA-1_A4_HGT_B0.8_CE_104
# CA-1_A6_HGT_B0.8_CEq_104
# CA-1_B1_HGT_B0.0_CE_benign_104
# CA-1_B5_HGT_B0.0_CEq_benign_104
# CA-1_B4_HGT_B0.8_CE_benign_104
# CA-1_B6_HGT_B0.8_CEq_benign_104
# mkdir: cannot create directory ‘analysis’: File exists
# /Core/home/rosiec/__research/HGT/raw_data/FinalData/CA_GrazingHypothesis_LongTermEvolution/analysis
#
# CA-1_Z1_HGT_B0.0 :  50
#    shortlabel :  CA-1_Z1_HGT_B0.0
#    skip :  []
#    longlabel :  Z1
# HGT
# B0.0
#    factors :  {'Bonus': 'B0.0', 'Quiesce': 'True', 'Exp': 'A', 'Env': 'Static'}
#    series :  CA-1
#    id :  Z1
#    dir :  CA-1_Z1_HGT_B0.0_104
#    filename :  None
#
# CA-1_Z2_noHGT_B0.0 :  49
#    shortlabel :  CA-1_Z2_noHGT_B0.0
#    skip :  []
#    longlabel :  Z2
# noHGT
# B0.0
#    factors :  {'Bonus': 'B0.0', 'Quiesce': 'True', 'Exp': 'B', 'Env': 'Static'}
#    series :  CA-1
#    id :  Z2
#    dir :  CA-1_Z2_noHGT_B0.0_104
#    filename :  None
#
# CA-1_Z3_noHGT_B0.0_CE :  46
#    shortlabel :  CA-1_Z3_noHGT_B0.0_CE
#    skip :  []
#    longlabel :  Z3
# noHGT
# B0.0
# CE
#    factors :  {'Bonus': 'B0.0', 'Quiesce': 'True', 'Exp': 'B', 'Env': 'CE'}
#    series :  CA-1
#    id :  Z3
#    dir :  CA-1_Z3_noHGT_B0.0_CE_104
#    filename :  None
#
# CA-1_Z4_noHGT_B0.0_CEq :  48
#    shortlabel :  CA-1_Z4_noHGT_B0.0_CEq
#    skip :  []
#    longlabel :  Z4
# noHGT
# B0.0
# CEq
#    factors :  {'Bonus': 'B0.0', 'Quiesce': 'False', 'Exp': 'B', 'Env': 'CE'}
#    series :  CA-1
#    id :  Z4
#    dir :  CA-1_Z4_noHGT_B0.0_CEq_104
#    filename :  None
#
# CA-1_Z5_noHGT_B0.0_CE_benign :  49
#    shortlabel :  CA-1_Z5_noHGT_B0.0_CE_benign
#    skip :  []
#    longlabel :  Z5
# noHGT
# B0.0
# CE
# benign
#    factors :  {'Bonus': 'B0.0', 'Quiesce': 'True', 'Exp': 'B', 'Env': 'CE'}
#    series :  CA-1
#    id :  Z5
#    dir :  CA-1_Z5_noHGT_B0.0_CE_benign_104
#    filename :  None
#
# CA-1_Z6_noHGT_B0.0_CEq_benign :  48
#    shortlabel :  CA-1_Z6_noHGT_B0.0_CEq_benign
#    skip :  []
#    longlabel :  Z6
# noHGT
# B0.0
# CEq
# benign
#    factors :  {'Bonus': 'B0.0', 'Quiesce': 'False', 'Env': 'CE'}
#    series :  CA-1
#    id :  Z6
#    dir :  CA-1_Z6_noHGT_B0.0_CEq_benign_104
#    filename :  None
#
# CA-1_Z7_HGT_B0.0_nologic77 :  50
#    shortlabel :  CA-1_Z7_HGT_B0.0_nologic77
#    skip :  []
#    longlabel :  Z7
# HGT
# B0.0
# nologic77
#    factors :  {'Bonus': 'B0.0', 'Quiesce': 'True', 'Exp': 'B', 'Env': 'Static'}
#    series :  CA-1
#    id :  Z7
#    dir :  CA-1_Z7_HGT_B0.0_nologic77_104
#    filename :  None
#
# CA-1_Z8_noHGT_B0.0_nologic77 :  49
#    shortlabel :  CA-1_Z8_noHGT_B0.0_nologic77
#    skip :  []
#    longlabel :  Z8
# noHGT
# B0.0
# nologic77
#    factors :  {'Bonus': 'B0.0', 'Quiesce': 'True', 'Exp': 'B', 'Env': 'Static'}
#    series :  CA-1
#    id :  Z8
#    dir :  CA-1_Z8_noHGT_B0.0_nologic77_104
#    filename :  None
#
# CA-1_A1_HGT_B0.0_CE :  47
#    shortlabel :  CA-1_A1_HGT_B0.0_CE
#    skip :  []
#    longlabel :  A1
# HGT
# B0.0
# CE
#    factors :  {'Bonus': 'B0.0', 'Quiesce': 'False', 'Exp': 'A', 'Env': 'CE'}
#    series :  CA-1
#    id :  A1
#    dir :  CA-1_A1_HGT_B0.0_CE_104
#    filename :  None
#
# CA-1_A5_HGT_B0.0_CEq :  49
#    shortlabel :  CA-1_A5_HGT_B0.0_CEq
#    skip :  []
#    longlabel :  A5
# HGT
# B0.0
# CEq
#    factors :  {'Bonus': 'B0.0', 'Quiesce': 'True', 'Exp': 'B', 'Env': 'CE'}
#    series :  CA-1
#    id :  A5
#    dir :  CA-1_A5_HGT_B0.0_CEq_104
#    filename :  None
#
# CA-1_A2_HGT_B0.8 :  45
#    shortlabel :  CA-1_A2_HGT_B0.8
#    skip :  []
#    longlabel :  A2
# HGT
# B0.8
#    factors :  {'Bonus': 'B0.8', 'Quiesce': 'True', 'Exp': 'A', 'Env': 'Static'}
#    series :  CA-1
#    id :  A2
#    dir :  CA-1_A2_HGT_B0.8_104
#    filename :  None
#
# CA-1_A3_HGT_B1.6 :  29
#    shortlabel :  CA-1_A3_HGT_B1.6
#    skip :  []
#    longlabel :  A3
# HGT
# B1.6
#    factors :  {'Bonus': 'B1.6', 'Quiesce': 'True', 'Exp': 'A', 'Env': 'Static'}
#    series :  CA-1
#    id :  A3
#    dir :  CA-1_A3_HGT_B1.6_104
#    filename :  None
#
# CA-1_A4_HGT_B0.8_CE :  43
#    shortlabel :  CA-1_A4_HGT_B0.8_CE
#    skip :  []
#    longlabel :  A4
# HGT
# B0.8
# CE
#    factors :  {'Bonus': 'B0.8', 'Quiesce': 'False', 'Exp': 'A', 'Env': 'CE'}
#    series :  CA-1
#    id :  A4
#    dir :  CA-1_A4_HGT_B0.8_CE_104
#    filename :  None
#
# CA-1_A6_HGT_B0.8_CEq :  42
#    shortlabel :  CA-1_A6_HGT_B0.8_CEq
#    skip :  []
#    longlabel :  A6
# HGT
# B0.8
# CEq
#    factors :  {'Bonus': 'B0.8', 'Quiesce': 'True', 'Exp': 'B', 'Env': 'CE'}
#    series :  CA-1
#    id :  A6
#    dir :  CA-1_A6_HGT_B0.8_CEq_104
#    filename :  None
#
# CA-1_B1_HGT_B0.0_CE_benign :  46
#    shortlabel :  CA-1_B1_HGT_B0.0_CE_benign
#    skip :  []
#    longlabel :  B1
# HGT
# B0.0
# CE
# benign
#    factors :  {'Bonus': 'B0.0', 'Quiesce': 'False', 'Exp': 'B', 'Env': 'CE'}
#    series :  CA-1
#    id :  B1
#    dir :  CA-1_B1_HGT_B0.0_CE_benign_104
#    filename :  None
#
# CA-1_B5_HGT_B0.0_CEq_benign :  50
#    shortlabel :  CA-1_B5_HGT_B0.0_CEq_benign
#    skip :  []
#    longlabel :  B5
# HGT
# B0.0
# CEq
# benign
#    factors :  {'Bonus': 'B0.0', 'Quiesce': 'True', 'Exp': 'B', 'Env': 'CE'}
#    series :  CA-1
#    id :  B5
#    dir :  CA-1_B5_HGT_B0.0_CEq_benign_104
#    filename :  None
#
# CA-1_B4_HGT_B0.8_CE_benign :  35
#    shortlabel :  CA-1_B4_HGT_B0.8_CE_benign
#    skip :  []
#    longlabel :  B4
# HGT
# B0.8
# CE
# benign
#    factors :  {'Bonus': 'B0.8', 'Quiesce': 'False', 'Exp': 'B', 'Env': 'CE'}
#    series :  CA-1
#    id :  B4
#    dir :  CA-1_B4_HGT_B0.8_CE_benign_104
#    filename :  None
#
# CA-1_B6_HGT_B0.8_CEq_benign :  40
#    shortlabel :  CA-1_B6_HGT_B0.8_CEq_benign
#    skip :  []
#    longlabel :  B6
# HGT
# B0.8
# CEq
# benign
#    factors :  {'Bonus': 'B0.8', 'Quiesce': 'True', 'Exp': 'B', 'Env': 'CE'}
#    series :  CA-1
#    id :  B6
#    dir :  CA-1_B6_HGT_B0.8_CEq_benign_104
#    filename :  None

# %%
def test_data_accessibility(treatments):
    # !pwd
    direct = treatments[treatments.keys()[0]]['dir']
    print "regular cat"
    # %cat ../{direct}001/data/log_average.dat | head -n 20
    print
    print "zcat"
    # %zcat ../{direct}001/data/log_average.dat* | head -n 20
    
test_data_accessibility(treatments)
# Out:
# /Core/home/rosiec/__research/HGT/raw_data/FinalData/CA_GrazingHypothesis_LongTermEvolution/analysis
# regular cat
# cat: ../CA-1_Z1_HGT_B0.0_104001/data/log_average.dat: No such file or directory
#
# zcat
# # Avida Fitness Data
# # Sun Sep 17 15:03:39 2017
# #  1: Update
# #  2: Fitness
# #  3: Fitness STE
# #  4: Fitness Variance
# #  5: Log Fitness
# #  6: Log Fitness STE
# #  7: Log Fitness Variance
#
# 0 0 0 0 -inf -nan -nan
# 100 0.24822 0.000144608 7.52814e-05 -1.39423 0.000710771 0.0018187
# 200 0.248201 0.000137715 6.8276e-05 -1.3942 0.000650761 0.00152456
# 300 0.247937 0.000177811 0.000113821 -1.39596 0.000984501 0.00348927
# 400 0.248043 0.000152227 8.34235e-05 -1.39501 0.000732263 0.00193035
# 500 0.24777 0.000173827 0.000108777 -1.39639 0.000849232 0.0025963
# 600 0.247465 0.000188502 0.000127883 -1.39784 0.000928183 0.00310063
# 700 0.247889 0.000170936 0.000105131 -1.39586 0.000827008 0.00246082
# 800 0.24805 0.000162786 9.53972e-05 -1.39512 0.000799292 0.00229993
# 900 0.248163 0.000175814 0.000111278 -1.39485 0.000874849 0.0027553
#
# gzip: stdout: Broken pipe

# %%
def test_scripts_accessibilty(treatments):
    import sys
    sys.path.append({scripts_path})
    # %run {scripts_path}/quickplot.py --help
    
test_scripts_accessibilty(treatments)
# Out:
# Usage: quickplot.py [options] outfile [input_file1 column1 "directory_glob1" name1 .. input_fileN columnN "directory_globN" nameN]
#
#
#
# Options:
#   -h, --help            show this help message and exit
#   -v, --verbose         print extra messages to stdout
#   -d, --debug_messages  print debug messages to stdout
#   --plotonly            Skip the aggregation step, and plot only, using
#                         existing data files.
#   --noplot              Skip the plotting step, only aggregate the data files.
#   -t TITLE, --title=TITLE
#                         set a different title than outfile (default)
#   -x XLABEL, --xlabel=XLABEL
#                         X-axis Label
#   -y YLABEL, --ylabel=YLABEL
#                         Y-axis Label
#   --include_chevrons    Include line marker glyphs in addition to color
#   --chevrons_by_members
#                         Make the chevrons track by members, along with line
#                         style
#   --data_members=MEMBER_COUNT
#                         Number of Components from a given data source
#                         (treatment)
#   --alt_axis=ALT_AXIS   Use an alternative axis for the Nth data source
#   -w Y_LABEL_ALT_AXIS, --ylabel_alt_axis=Y_LABEL_ALT_AXIS
#                         Alternative Y-axis Label
#   --xtick_multiplier=XTICK_MULTIPLIER
#                         X-axis Tick Multipliers
#   --ylog                Y-axis logarithmic scale
#   --ylim_max=YLIM_MAX   Set the ylim max
#   --ylim_min=YLIM_MIN   Set the ylim min
#   --error               include error bars - error values will be calculated
#                         from data using bootstrap
#   --samples=SAMPLES     how many samples to draw for bootstrap?
#   --end_at=END_AT       Stop plotting at datapoint <end_at>

# %% [markdown]
# ### Helper Functions

# %% [markdown]
# #### Dataset Manipulation (Grab/Thin)

# %%
def grab_set(ts, factor=None, series=None):
    if not factor and not series:
        return ts
    if series and factor:
        thing = [ts[t]['shortlabel'] for t in ts if 
               (factor in ts[t]['factors'].values() and 
               ts[t]['series'] == series)]
        
        #print "HI", series, factor
        #print thing
        
    elif factor:
        thing = [ts[t]['shortlabel'] for t in ts if 
               factor in ts[t]['factors'].values()]
    elif series:
        thing = [ts[t]['shortlabel'] for t in ts if 
               ts[t]['series'] == series]
        
    subset = collections.OrderedDict()
    for t in thing:
        subset[t] = ts[t]
        
    return subset

def test_grab_set(treatments):

    print "Subsetting"
    print treatments.keys()
    print
    print "Subset, selecting on series AC-1"
    print grab_set(series="AC-1", ts=treatments).keys()

# %%
## THIN SETS
def thin_set(ts, factor=None, series=None):

    thing = ts.keys()
    
    if factor:
        for t in ts.keys():
            if factor in ts[t]['factors'].values():
                thing.remove(t)
                
    if series:
        for t in ts.keys():
            if series == ts[t]['series']:
                thing.remove(t)
        
    subset = collections.OrderedDict()
    for t in thing:
        subset[t] = ts[t]
        
    return subset

def test_thin_set(treatments):
    print
    print "Thinning Set"
    print treatments.keys()
    thingy = grab_set(series="AC-2", factor="Homol", ts=treatments)
    print
    print "Subset selecting by HOMOL factor"
    print thingy.keys()
    print
    print "Thinned by removing MRI factor"
    print thin_set(factor="MRI", ts=thingy).keys()

# %%
def factorset(treatments):
    factorset = None
    for t in ac2_set:
        if not factorset:
            factorset = set(treatments[t]['factors'].keys())
        factorset &= set(treatments[t]['factors'].keys())
    return list(factorset)

# %%
def matchingcolumns(dataset1, dataset2):
    return list( set(dataset1.columns) & set(dataset2.columns) )

# %% [markdown]
# # Task Performance

# %%
# %pwd
# Out:
# u'/Core/home/rosiec/__research/HGT/raw_data/FinalData/CA_GrazingHypothesis_LongTermEvolution/analysis'

# %%
# %pwd 

def generate_data(use_pickled=False):
    picklename = "task_performance.pd.pickle"

    ## check for pickling!
    if use_pickled and os.path.exists(picklename):
        task_perf = pd.read_pickle(picklename)
        return task_perf
        
    
    task_perf = []
    tct = 0
    for t in treatments:  
        tct += 1
        print t

        dfs = []

        for i in range(1,51):

            bit = str(i).zfill(2) ## runs from 01 to 50
            globstring = '../*' + treatments[t]['dir'] + "*" + bit + '/data/tasks.dat*'
            dfiles = sorted(glob.glob(globstring))

            for item in dfiles:
                sys.stdout.write('.')

                df = pd.read_csv(item, header=None, comment="#", 
                                  delimiter=' ', usecols=[0]+range(10, 78),
                                  skipinitialspace=True) #, names=fields)


                df['id'] = [ treatments[t]['id'] ] * len(df)
                df['treatment'] = [t] * len(df)
                df['label'] = [ treatments[t]['longlabel'] ] * len(df)
                df['replicate'] = [i] * len(df)


                ## TODO, collect the booled bits.
                ## figure out how to do this efficiently, while fighting with the fucking series.
                col_list = list(df)
                col_list.remove(0)

                bleh = df[col_list].where(lambda x : x > 3.6, axis=1)
                bleh = bleh.fillna(value=0, axis=1).astype(bool)

                running = [False] * len(bleh.iloc[0].tolist())
                running_post_reward = [False] * len(bleh.iloc[0].tolist())
                running_ct = []
                running_post_reward_ct = []

                #bleh.describe()

                #print len(bleh)

                for i in range(len(bleh)):
                    #sys.stdout.write("-")
                    running = [k | j for k,j in zip(running, bleh.iloc[i].tolist())]
                    running_ct.append(sum( [int(l) for l in running] ))

                    if (i * 100) >= 200000:
                        #sys.stdout.write(":")
                        #print "post"
                        running_post_reward = [k | j for k,j in zip(running_post_reward, bleh.iloc[i].tolist())]
                        running_post_reward_ct.append(sum( [int(l) for l in running_post_reward] ))
                        #print running_post_reward_ct[-1], running_ct[-1]
                    else:
                        running_post_reward_ct.append(0)




                df['new_tasks'] = running_ct
                df['new_tasks_post_reward'] = running_post_reward_ct

                dfs.append( df )

        intermediate = pd.concat(dfs)

        col_list = list(intermediate)
        col_list.remove(0)

        dta = pd.DataFrame()

        dta['update'] = intermediate[0]


        dta['id'] = intermediate['id']
        dta['label'] = intermediate['label']
        dta['treatment'] = intermediate['treatment']

        dta['replicate'] = intermediate['replicate']

        dta['new_tasks'] = intermediate['new_tasks']
        dta['new_tasks_post_reward'] = intermediate['new_tasks_post_reward']

        dta['task_sum'] = intermediate[col_list].sum(axis=1)

        bleh = intermediate[col_list].where(lambda x : x > 3.6, axis=1)
        bleh = bleh.fillna(value=0, axis=1).astype(bool).sum(axis=1)   
        dta['task_ct'] = bleh

        #print dta.describe()
        #print dta.head()

        task_perf.append(dta)

        print "  done"

    task_perf = pd.concat(task_perf)
    
    
    
    ## if we generate the data, pickle it
    task_perf.to_pickle(picklename)

    return task_perf

task_perf = generate_data(use_pickled=True) 
print task_perf.describe()
print task_perf.head()
# Out:
#              update     replicate     new_tasks  new_tasks_post_reward  \
# count  3.260815e+06  3.260815e+06  3.260815e+06           3.260815e+06
# mean   2.000000e+05  2.528834e+01  2.052938e+01           1.052703e+01
# std    1.154989e+05  1.443570e+01  1.155735e+01           1.380430e+01
# min    0.000000e+00  1.000000e+00  3.000000e+00           0.000000e+00
# 25%    1.000000e+05  1.300000e+01  1.300000e+01           0.000000e+00
# 50%    2.000000e+05  2.500000e+01  1.900000e+01           4.000000e+00
# 75%    3.000000e+05  3.800000e+01  2.600000e+01           1.800000e+01
# max    4.000000e+05  5.000000e+01  7.200000e+01           7.200000e+01
#
#            task_sum       task_ct
# count  3.260815e+06  3.260815e+06
# mean   7.290864e+03  1.012825e+01
# std    1.417361e+04  7.196372e+00
# min    4.000000e+00  3.000000e+00
# 25%    3.122000e+03  6.000000e+00
# 50%    3.491000e+03  8.000000e+00
# 75%    5.204000e+03  1.100000e+01
# max    1.857470e+05  7.400000e+01
#    update  id          label         treatment  replicate  new_tasks  \
# 0       0  Z1  Z1\nHGT\nB0.0  CA-1_Z1_HGT_B0.0          1          3
# 1     100  Z1  Z1\nHGT\nB0.0  CA-1_Z1_HGT_B0.0          1          4
# 2     200  Z1  Z1\nHGT\nB0.0  CA-1_Z1_HGT_B0.0          1          4
# 3     300  Z1  Z1\nHGT\nB0.0  CA-1_Z1_HGT_B0.0          1          4
# 4     400  Z1  Z1\nHGT\nB0.0  CA-1_Z1_HGT_B0.0          1          4
#
#    new_tasks_post_reward  task_sum  task_ct
# 0                      0         4        3
# 1                      0        44        5
# 2                      0        81        5
# 3                      0        77        5
# 4                      0        96        5

# %%
data = task_perf

## no HGT, vs HGT
noHGT = data [(data['id'] == 'Z2') |
            (data['id'] == "Z3") | (data['id'] == 'Z4') |
            (data['id'] == "Z5") | (data['id'] == 'Z6') ]
noHGT['factor'] = ['noHGT'] * len(noHGT)

HGT = data [(data['id'] == 'Z1') |
            (data['id'] == "A1") | (data['id'] == 'A5') |
             (data['id'] == "B1") | (data['id'] == 'B5') ]
HGT['factor'] = ['HGT'] * len(HGT)
noHGT_HGT = pd.concat([noHGT, HGT])



B0 = data [(data['id'] == 'Z1') |
            (data['id'] == "A1") | (data['id'] == 'A5') |
             (data['id'] == "B1") | (data['id'] == 'B5') ]
B0['factor'] = ['0.0'] * len(B0)

B08 = data [(data['id'] == "A2") |
            (data['id'] == "A4") | (data['id'] == 'A6') |
            (data['id'] == "B4") | (data['id'] == 'B6')]
B08['factor'] = ['0.8'] * len(B08)
B0_B08 = pd.concat([B0, B08])

# %%
def ts_violin(data, field, ylabel=None, 
              huename=None, title=None):

    ## collect data for violin
    piece = data.loc[data['update'] == 400000]
    def label_env(row):
        if 'CEq_benign' in row['treatment']:
            return 'CEq_benign'
        elif 'CE_benign' in row['treatment']:
            return 'CE_benign'
        elif 'CEq' in row['treatment']:
            return 'CEq'
        elif 'CE' in row['treatment']:
            return 'CE'
        else:
            return 'Static'
    piece['Env'] = piece.apply (lambda row: label_env(row), axis=1)
    
    colorp = sns.color_palette("colorblind")
#    colorp = [colorp[1], colorp[2], colorp[3], colorp[0], colorp[5]]
    colorp = ['white', colorp[2], colorp[3], colorp[0], colorp[5]]
    labels = list(piece['Env'].unique())
    colors = {}
    for l,c in zip(labels,colorp):
        colors[l] = c
    
#    print colors



    labels = list(piece['treatment'].unique())
    colors2 = {}
    for l,c in zip(labels,colorp):
        colors2[l] = c
    print colors2

    ## prep colors and linestyles
#     colors = ['yellow', 'yellow', 
#           'magenta', 'purple', 'cyan', 'blue',
#          'magenta', 'purple', 'cyan', 'blue']
#     linestyles = ['--', '-', '-', '-', '-', '-', 
#                   '--', '--', '--', '--']

    ## prep plot
    plt.rcParams['figure.figsize'] = (20, 10)
    if title:
        plt.suptitle(title)

    ## timeseries
    plt.subplot(121)
    ax = sns.tsplot(time="update", value=field,
                    unit="replicate", 
                    condition="treatment",
                    data=data,
                    color=colors2,
                    #palette=colors,
                    ci=[95])
    #for line, style in zip(ax.lines, linestyles):
    #    line.set_linestyle(style)
    ax.legend(title='Treatment')
    if ylabel:
        ax.set_ylabel(ylabel)

    ## violin + swarm
    plt.subplot(122)
    
    hue = None
    split = False
    if huename:
        split = True
        hue = 'factor'
    
    
    ax = sns.violinplot(x="Env", y=field, hue=hue, 
                   data=piece, 
                   split=split, 
                   scale="count", scale_hue=False, bw=.3,
                        linewidth=0.3,
                  edgecolor="gray",
                    palette=colors,
                   inner="quart")
    sns.swarmplot(x="Env", y=field, hue=hue, 
                  data=piece, 
                  linewidth=0.3,
                  edgecolor="gray",
                    palette=colors,
                  split=split)    
    handles, labels = ax.get_legend_handles_labels()
    if huename:
        ax.legend(handles[:2], labels[:2], title=huename)
    else:
        ax.legend(handles[:2], labels[:2])
    if ylabel:
        ax.set_ylabel(ylabel)

# %%
ts_violin(noHGT.loc[noHGT['update'] >= 200000], "new_tasks_post_reward", ylabel="Tasks Discovered", 
          #huename='Instruction',
          #colors=colors,
          title="New Task Discovery Post Logic 77\noHGT")
# Out:
# {'CA-1_Z3_noHGT_B0.0_CE': (0.8352941176470589, 0.3686274509803922, 0.0), 'CA-1_Z5_noHGT_B0.0_CE_benign': (0.0, 0.4470588235294118, 0.6980392156862745), 'CA-1_Z4_noHGT_B0.0_CEq': (0.8, 0.4745098039215686, 0.6549019607843137), 'CA-1_Z6_noHGT_B0.0_CEq_benign': (0.33725490196078434, 0.7058823529411765, 0.9137254901960784), 'CA-1_Z2_noHGT_B0.0': 'white'}

# %%
ts_violin(noHGT, "new_tasks", ylabel="Tasks Discovered", 
          #huename='Instruction', 
          title="New Task Discovery\noHGT vs HGT")
# Out:
# {'CA-1_Z3_noHGT_B0.0_CE': (0.8352941176470589, 0.3686274509803922, 0.0), 'CA-1_Z5_noHGT_B0.0_CE_benign': (0.0, 0.4470588235294118, 0.6980392156862745), 'CA-1_Z4_noHGT_B0.0_CEq': (0.8, 0.4745098039215686, 0.6549019607843137), 'CA-1_Z6_noHGT_B0.0_CEq_benign': (0.33725490196078434, 0.7058823529411765, 0.9137254901960784), 'CA-1_Z2_noHGT_B0.0': 'white'}

# %%
ts_violin(noHGT_HGT, "new_tasks", ylabel="Tasks Discovered", 
          huename='Instruction', 
          title="New Task Discovery\noHGT vs HGT")

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
newpal = sns.color_palette()[1:] + sns.color_palette()[0:1]
ts_violin(B0_B08, "new_tasks", ylabel="Tasks Discovered", 
          huename='Bonus', 
          title="New Task Discovery\nNo Bonus vs Bonus 0.8",
         palcolors=newpal)

# %%
part = noHGT_HGT.loc[noHGT_HGT['update'] >= 200000]
ts_violin(part, "new_tasks_post_reward", 
          ylabel="Tasks Discovered", 
          huename='Instruction', 
          title="New Task Discovery After Logic-77 Introduced\noHGT vs HGT")

# %%
newpal = sns.color_palette()[1:] + sns.color_palette()[0:1]
part = B0_B08.loc[B0_B08['update'] >= 200000]
ts_violin(part, "new_tasks_post_reward", 
          ylabel="Tasks Discovered", 
          huename='Bonus', 
          title="New Task Discovery After Logic-77 Introduced\nNo Bonus vs Bonus 0.8",
          palcolors=newpal)
